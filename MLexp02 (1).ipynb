# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/placement_predict_50k Dataset.csv')

# %%
# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    StudentID  Gender       City CollegeTier Stream Specialisation Hostel  \
# 0          1    Male  Ahmedabad       Tier2    ECE     Networking     No
# 1          2  Female     Mumbai       Tier2    ECE    DataScience    Yes
# 2          3    Male    Kolkata       Tier2     IT    DataScience    Yes
# 3          4    Male     Jaipur       Tier1     CS             AI     No
# 4          5    Male       Pune       Tier2     IT    DataScience    Yes
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 0                No       6.02       6.54  ...             0
# 1               Yes       5.84       5.12  ...             0
# 2                No       4.91       5.29  ...             0
# 3                No       7.67       8.03  ...             0
# 4                No       8.14       8.97  ...             1
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# 0               66.7               2.2             49.4                47.8
# 1               48.2               2.4             26.7                25.8
# 2               73.8               2.8             67.7                41.5
# 3               69.8               2.7             66.9                48.0
# 4               73.1               2.1             71.7                61.7
#
#    ExtraCurricular  CGPA_Tier  PlacementStatus  IsAnomaly  Salary Package
# 0                0        Low                0          0            0.00
# 1                0        Low                0          0            0.00
# 2                0        Low                1          0            3.89
# 3                0        Mid                1          0            8.37
# 4                1       High                1          0           18.99
#
# [5 rows x 32 columns]

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
df.head(8)
# Out:
#    StudentID  Gender       City CollegeTier      Stream Specialisation Hostel  \
# 0          1    Male  Ahmedabad       Tier2         ECE     Networking     No
# 1          2  Female     Mumbai       Tier2         ECE    DataScience    Yes
# 2          3    Male    Kolkata       Tier2          IT    DataScience    Yes
# 3          4    Male     Jaipur       Tier1          CS             AI     No
# 4          5    Male       Pune       Tier2          IT    DataScience    Yes
# 5          6    Male  Ahmedabad       Tier2          EE     Networking     No
# 6          7    Male  Hyderabad       Tier2  Mechanical     Networking    Yes
# 7          8    Male      Delhi       Tier2  Mechanical       Embedded    Yes
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 0                No       6.02       6.54  ...             0
# 1               Yes       5.84       5.12  ...             0
# 2                No       4.91       5.29  ...             0
# 3                No       7.67       8.03  ...             0
# 4                No       8.14       8.97  ...             1
# 5                No      10.00      10.00  ...             1
# 6                No       8.70       9.55  ...             2
# 7                No       5.87       5.64  ...             0
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# 0               66.7               2.2             49.4                47.8
# 1               48.2               2.4             26.7                25.8
# 2               73.8               2.8             67.7                41.5
# 3               69.8               2.7             66.9                48.0
# 4               73.1               2.1             71.7                61.7
# 5               81.5               3.9              NaN                75.3
# 6               76.5               4.6             83.0                61.5
# 7                NaN               2.0             35.2                27.8
#
#    ExtraCurricular  CGPA_Tier  PlacementStatus  IsAnomaly  Salary Package
# 0                0        Low                0          0            0.00
# 1                0        Low                0          0            0.00
# 2                0        Low                1          0            3.89
# 3                0        Mid                1          0            8.37
# 4                1       High                1          0           18.99
# 5                0       High                1          0           18.17
# 6                1       High                1          0           25.52
# 7                0        Low                0          0            0.00
#
# [8 rows x 32 columns]

# %%
df.tail(5)
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49996      49997    Male  Bangalore       Tier2          EE             AI
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
# 49999      50000  Female      Delhi       Tier2         ECE     Networking
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 49995     No                No       7.84       8.45  ...             1
# 49996     No                No       6.08       6.12  ...             2
# 49997    Yes               Yes       5.69       6.09  ...             0
# 49998     No                No       6.02       6.31  ...             1
# 49999     No                No       6.51       6.37  ...             0
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 49995               75.8               3.9             54.2
# 49996               81.4               3.8             56.1
# 49997                NaN               3.1             49.1
# 49998               74.5               2.5              NaN
# 49999               58.3               2.3             29.5
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 49995                 NaN                0       High                1
# 49996                67.7                0        Low                1
# 49997                57.7                1        Low                0
# 49998                48.3                1        Low                0
# 49999                30.6                0        Low                0
#
#        IsAnomaly  Salary Package
# 49995          0           18.14
# 49996          0            3.36
# 49997          0            0.00
# 49998          0            0.00
# 49999          0            0.00
#
# [5 rows x 32 columns]

# %%
df.tail(25)
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 49975      49976    Male      Kochi       Tier1         ECE    DataScience
# 49976      49977    Male  Hyderabad       Tier2          IT     Networking
# 49977      49978    Male       Pune       Tier2          CS             AI
# 49978      49979  Female  Bangalore       Tier3  Mechanical     Networking
# 49979      49980    Male       Pune       Tier2       Civil       Embedded
# 49980      49981    Male    Kolkata       Tier2          CS    DataScience
# 49981      49982  Female  Bangalore       Tier1         ECE     Networking
# 49982      49983  Female  Ahmedabad       Tier2          EE    DataScience
# 49983      49984    Male  Bangalore       Tier3          CS             AI
# 49984      49985  Female  Bangalore       Tier2          CS             AI
# 49985      49986  Female     Mumbai       Tier2         ECE    DataScience
# 49986      49987    Male  Hyderabad       Tier2          CS             AI
# 49987      49988    Male  Ahmedabad       Tier3          EE       Embedded
# 49988      49989    Male      Delhi       Tier1          EE     Networking
# 49989      49990  Female     Mumbai       Tier2          CS     Networking
# 49990      49991    Male      Delhi       Tier2          IT    DataScience
# 49991      49992  Female    Chennai       Tier1          CS     Networking
# 49992      49993    Male  Ahmedabad       Tier1          CS       Embedded
# 49993      49994  Female    Kolkata       Tier2          CS             AI
# 49994      49995  Female    Kolkata       Tier2          CS    DataScience
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49996      49997    Male  Bangalore       Tier2          EE             AI
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
# 49999      50000  Female      Delhi       Tier2         ECE     Networking
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 49975     No                No       6.49       6.45  ...             1
# 49976    Yes                No       5.75       6.22  ...             0
# 49977     No                No       6.57       6.26  ...             1
# 49978     No                No       9.78       9.77  ...             1
# 49979    Yes               Yes       6.16       6.62  ...             1
# 49980     No               Yes       7.99       7.61  ...             2
# 49981    Yes                No       8.47       7.95  ...             2
# 49982     No               Yes       5.85       6.35  ...             0
# 49983     No                No       5.20       5.18  ...             0
# 49984    Yes                No       7.26       7.19  ...             1
# 49985     No                No       6.91       7.02  ...             0
# 49986     No               Yes       5.55       5.67  ...             0
# 49987    Yes                No       7.25       6.96  ...             1
# 49988     No                No       5.74       5.57  ...             2
# 49989    Yes                No       6.97       6.64  ...             0
# 49990    Yes                No       7.75       7.21  ...             0
# 49991     No                No       7.17       7.46  ...             1
# 49992     No               Yes       5.89       5.88  ...             1
# 49993    Yes               Yes       8.13       8.52  ...             1
# 49994    Yes                No       7.46       7.37  ...             0
# 49995     No                No       7.84       8.45  ...             1
# 49996     No                No       6.08       6.12  ...             2
# 49997    Yes               Yes       5.69       6.09  ...             0
# 49998     No                No       6.02       6.31  ...             1
# 49999     No                No       6.51       6.37  ...             0
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 49975               65.4               NaN             46.3
# 49976               57.3               3.6             47.8
# 49977               47.8               1.8             33.7
# 49978               98.8               1.9             97.0
# 49979               99.7               3.3             99.8
# 49980               68.7               3.3             64.5
# 49981               78.5               4.2             83.7
# 49982               31.9               3.7              5.1
# 49983               46.9               1.3              NaN
# 49984               69.0               2.3             67.9
# 49985               67.8               3.2             68.6
# 49986               68.7               3.8             44.9
# 49987               67.9               3.4             49.2
# 49988               79.2               4.1             66.4
# 49989               68.1               4.1             50.1
# 49990               66.5               3.8             56.4
# 49991               72.6               1.5             57.4
# 49992               74.5               2.9              NaN
# 49993               68.4               4.1             90.0
# 49994               57.2               2.6             55.3
# 49995               75.8               3.9             54.2
# 49996               81.4               3.8             56.1
# 49997                NaN               3.1             49.1
# 49998               74.5               2.5              NaN
# 49999               58.3               2.3             29.5
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 49975                49.6                1        Mid                0
# 49976                57.6                0        Low                0
# 49977                31.3                0        Mid                0
# 49978                48.1                1       High                1
# 49979                42.9                1        Mid                1
# 49980                76.3                0       High                1
# 49981                68.4                0       High                1
# 49982                43.3                0        Low                0
# 49983                38.8                0        Low                0
# 49984                47.7                0        Mid                1
# 49985                53.4                0        Mid                1
# 49986                53.4                1        Low                0
# 49987                43.2                0        Mid                1
# 49988                69.8                0        Low                1
# 49989                60.7                0        Mid                1
# 49990                61.7                1        Mid                1
# 49991                58.1                0        Mid                1
# 49992                44.7                0        Low                0
# 49993                75.1                1       High                1
# 49994                47.0                0        Mid                1
# 49995                 NaN                0       High                1
# 49996                67.7                0        Low                1
# 49997                57.7                1        Low                0
# 49998                48.3                1        Low                0
# 49999                30.6                0        Low                0
#
#        IsAnomaly  Salary Package
# 49975          0            0.00
# 49976          0            0.00
# 49977          0            0.00
# 49978          1           18.17
# 49979          1            8.63
# 49980          0           18.84
# 49981          0           18.81
# 49982          1            0.00
# 49983          0            0.00
# 49984          0            8.54
# 49985          0            8.17
# 49986          0            0.00
# 49987          0            8.57
# 49988          0            3.45
# 49989          0            8.92
# 49990          0            8.92
# 49991          0            8.49
# 49992          0            0.00
# 49993          0           22.68
# 49994          0            8.08
# 49995          0           18.14
# 49996          0            3.36
# 49997          0            0.00
# 49998          0            0.00
# 49999          0            0.00
#
# [25 rows x 32 columns]

# %%
df.shape
# Out:
# (50000, 32)

# %%
df['StudentID']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 49995    49996
# 49996    49997
# 49997    49998
# 49998    49999
# 49999    50000
# Name: StudentID, Length: 50000, dtype: int64

# %%
df.columns
# Out:
# Index(['StudentID', 'Gender', 'City', 'CollegeTier', 'Stream',
#        'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'SGPA_Sem1',
#        'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6',
#        'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships',
#        'Projects', 'Workshops', 'Certifications', 'Publications',
#        'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore',
#        'MockInterviewScore', 'ExtraCurricular', 'CGPA_Tier', 'PlacementStatus',
#        'IsAnomaly', 'Salary Package'],
#       dtype='object')

# %%
df.dtypes
# Out:
# StudentID               int64
# Gender                 object
# City                   object
# CollegeTier            object
# Stream                 object
# Specialisation         object
# Hostel                 object
# HistoryOfBacklogs      object
# SGPA_Sem1             float64
# SGPA_Sem2             float64
# SGPA_Sem3             float64
# SGPA_Sem4             float64
# SGPA_Sem5             float64
# SGPA_Sem6             float64
# SGPA_Sem7             float64
# SGPA_Sem8             float64
# CGPA                  float64
# AttendancePercent     float64
# Internships             int64
# Projects                int64
# Workshops             float64
# Certifications          int64
# Publications            int64
# AptitudeTestScore     float64
# SoftSkillsRating      float64
# CodingTestScore       float64
# MockInterviewScore    float64
# ExtraCurricular         int64
# CGPA_Tier              object
# PlacementStatus         int64
# IsAnomaly               int64
# Salary Package        float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    16
# int64       8
# object      8
# Name: count, dtype: int64

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_data
# Out:
#                     Missing Values  Percentage
# StudentID                        0       0.000
# Gender                           0       0.000
# City                             0       0.000
# CollegeTier                      0       0.000
# Stream                           0       0.000
# Specialisation                   0       0.000
# Hostel                           0       0.000
# HistoryOfBacklogs                0       0.000
# SGPA_Sem1                        0       0.000
# SGPA_Sem2                        0       0.000
# SGPA_Sem3                        0       0.000
# SGPA_Sem4                        0       0.000
# SGPA_Sem5                        0       0.000
# SGPA_Sem6                        0       0.000
# SGPA_Sem7                        0       0.000
# SGPA_Sem8                        0       0.000
# CGPA                             0       0.000
# AttendancePercent                0       0.000
# Internships                      0       0.000
# Projects                         0       0.000
# Workshops                     4488       8.976
# Certifications                   0       0.000
# Publications                     0       0.000
# AptitudeTestScore             4029       8.058
# SoftSkillsRating              3526       7.052
# CodingTestScore               2976       5.952
# MockInterviewScore            4957       9.914
# ExtraCurricular                  0       0.000
# CGPA_Tier                        0       0.000
# PlacementStatus                  0       0.000
# IsAnomaly                        0       0.000
# Salary Package                   0       0.000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [StudentID, Gender, City, CollegeTier, Stream, Specialisation, Hostel, HistoryOfBacklogs, SGPA_Sem1, SGPA_Sem2, SGPA_Sem3, SGPA_Sem4, SGPA_Sem5, SGPA_Sem6, SGPA_Sem7, SGPA_Sem8, CGPA, AttendancePercent, Internships, Projects, Workshops, Certifications, Publications, AptitudeTestScore, SoftSkillsRating, CodingTestScore, MockInterviewScore, ExtraCurricular, CGPA_Tier, PlacementStatus, IsAnomaly, Salary Package]
# Index: []
#
# [0 rows x 32 columns]
# ----------------------------------------

# %%
df[df['AptitudeTestScore'].isnull()]
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 7              8    Male      Delhi       Tier2  Mechanical       Embedded
# 13            14    Male      Delhi       Tier1          CS             AI
# 18            19    Male  Bangalore       Tier2  Mechanical       Embedded
# 29            30  Female       Pune       Tier2       Civil     Networking
# 33            34    Male      Kochi       Tier3       Civil             AI
# ...          ...     ...        ...         ...         ...            ...
# 49935      49936    Male  Bangalore       Tier3         ECE       Embedded
# 49943      49944    Male     Jaipur       Tier3          CS    DataScience
# 49947      49948  Female  Bangalore       Tier1          CS     Networking
# 49961      49962    Male      Delhi       Tier2          CS    DataScience
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 7        Yes                No       5.87       5.64  ...             0
# 13        No                No      10.00      10.00  ...             1
# 18        No                No       6.97       6.53  ...             0
# 29       Yes                No       9.94       9.85  ...             2
# 33       Yes                No       4.52       4.06  ...             1
# ...      ...               ...        ...        ...  ...           ...
# 49935     No                No       5.73       5.73  ...             1
# 49943     No               Yes       5.28       5.53  ...             0
# 49947     No                No       9.75      10.00  ...             1
# 49961    Yes                No       7.10       7.00  ...             2
# 49997    Yes               Yes       5.69       6.09  ...             0
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# 7                    NaN               2.0             35.2
# 13                   NaN               NaN             87.9
# 18                   NaN               1.3             57.9
# 29                   NaN               4.8             60.3
# 33                   NaN               2.1             27.4
# ...                  ...               ...              ...
# 49935                NaN               2.0             28.6
# 49943                NaN               NaN              NaN
# 49947                NaN               4.2             55.6
# 49961                NaN               NaN             98.5
# 49997                NaN               3.1             49.1
#
#        MockInterviewScore  ExtraCurricular  CGPA_Tier  PlacementStatus  \
# 7                    27.8                0        Low                0
# 13                   86.8                1       High                1
# 18                   56.6                0        Mid                0
# 29                   89.3                1       High                1
# 33                   34.6                1        Low                0
# ...                   ...              ...        ...              ...
# 49935                32.5                0        Low                0
# 49943                26.0                0        Low                0
# 49947                63.1                1       High                1
# 49961                75.7                1        Mid                1
# 49997                57.7                1        Low                0
#
#        IsAnomaly  Salary Package
# 7              0            0.00
# 13             0           18.11
# 18             0            0.00
# 29             0           25.15
# 33             0            0.00
# ...          ...             ...
# 49935          0            0.00
# 49943          0            0.00
# 49947          0           25.59
# 49961          0            8.49
# 49997          0            0.00
#
# [4029 rows x 32 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#           StudentID     SGPA_Sem1     SGPA_Sem2     SGPA_Sem3     SGPA_Sem4  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   25000.500000      7.210583      7.222243      7.235398      7.247290
# std    14433.901067      1.517846      1.532008      1.551632      1.570629
# min        1.000000      4.000000      4.000000      4.000000      4.000000
# 25%    12500.750000      6.090000      6.090000      6.080000      6.070000
# 50%    25000.500000      7.190000      7.210000      7.220000      7.240000
# 75%    37500.250000      8.340000      8.360000      8.400000      8.430000
# max    50000.000000     10.000000     10.000000     10.000000     10.000000
#
#           SGPA_Sem5     SGPA_Sem6     SGPA_Sem7     SGPA_Sem8          CGPA  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       7.258639      7.274511      7.282720      7.293704      7.246154
# std        1.587829      1.603261      1.621605      1.638112      1.615686
# min        4.000000      4.000000      4.000000      4.000000      4.000000
# 25%        6.070000      6.080000      6.060000      6.060000      6.040000
# 50%        7.260000      7.280000      7.300000      7.310000      7.250000
# 75%        8.460000      8.500000      8.520000      8.560000      8.480000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...  Certifications  Publications  AptitudeTestScore  SoftSkillsRating  \
# count  ...    50000.000000  50000.000000       45971.000000      46474.000000
# mean   ...        1.931420      0.735460          68.859261          3.154211
# std    ...        1.175391      0.717167          15.365230          0.981333
# min    ...        0.000000      0.000000          30.000000          1.000000
# 25%    ...        1.000000      0.000000          58.500000          2.400000
# 50%    ...        2.000000      1.000000          69.900000          3.200000
# 75%    ...        3.000000      1.000000          79.700000          3.900000
# max    ...        5.000000      3.000000         100.000000          5.000000
#
#        CodingTestScore  MockInterviewScore  ExtraCurricular  PlacementStatus  \
# count     47024.000000         45043.00000     50000.000000     50000.000000
# mean         57.411273            55.40853         0.533000         0.657120
# std          20.979679            17.52218         0.498915         0.474677
# min           0.000000            15.90000         0.000000         0.000000
# 25%          45.900000            44.20000         0.000000         0.000000
# 50%          57.700000            54.70000         1.000000         1.000000
# 75%          73.300000            69.20000         1.000000         1.000000
# max         100.000000           100.00000         1.000000         1.000000
#
#           IsAnomaly  Salary Package
# count  50000.000000    50000.000000
# mean       0.035000        9.536119
# std        0.183782        8.824561
# min        0.000000        0.000000
# 25%        0.000000        0.000000
# 50%        0.000000        8.430000
# 75%        0.000000       18.410000
# max        1.000000       26.000000
#
# [8 rows x 24 columns]

# %%
df["PlacementStatus"].value_counts()
# Out:
# PlacementStatus
# 1    32856
# 0    17144
# Name: count, dtype: int64

# %%
(df["PlacementStatus"].value_counts(normalize=True) * 100).round(2)
# Out:
# PlacementStatus
# 1    65.71
# 0    34.29
# Name: proportion, dtype: float64
